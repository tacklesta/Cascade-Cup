# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('train_age_dataset.csv',index_col="userId")

df_ = pd.read_csv("test_age_dataset.csv",index_col="userId") 

df = df.iloc[:,1:]

df_ = df_.iloc[:,1:]

#df_.head()

# %%
#index_col = exp[exp["creations"]==0].index

# %%
#exp.drop(index_col, inplace = True)

# %%
#exp.creations.value_counts()

# %%
#sns.kdeplot(exp["creations"])

# %%
df.head()
# Out:
#           tier  gender  following_rate  followers_avg_age  following_avg_age  \
# userId
# 48958844     2       1             0.0                0.0                0.0
# 51100441     2       2             0.0                0.0                0.0
# 6887426      2       1             0.0                0.0                0.0
# 50742404     2       1             0.0                0.0                0.0
# 45589200     2       2             0.0                0.0                0.0
#
#           max_repetitive_punc  num_of_hashtags_per_action  \
# userId
# 48958844                    0                         0.0
# 51100441                    0                         0.0
# 6887426                     0                         0.0
# 50742404                    0                         0.0
# 45589200                    0                         0.0
#
#           emoji_count_per_action  punctuations_per_action  \
# userId
# 48958844                     0.0                 0.000000
# ...

# %%
#df.tier.unique()

# %%
df.describe().T
# Out:
#                                     count        mean           std       min  \
# tier                             488877.0    1.975382      0.430707  1.000000
# gender                           488877.0    1.213037      0.409454  1.000000
# following_rate                   488877.0    0.082233      2.467781  0.000000
# followers_avg_age                488877.0    0.347520      0.816334  0.000000
# following_avg_age                488877.0    0.403049      0.925291  0.000000
# max_repetitive_punc              488877.0    0.739748      3.075954  0.000000
# num_of_hashtags_per_action       488877.0    0.000277      0.012221  0.000000
# emoji_count_per_action           488877.0    0.000981      0.020381  0.000000
# punctuations_per_action          488877.0    0.012805      0.159553  0.000000
# number_of_words_per_action       488877.0    0.179148      0.647588  0.000000
# avgCompletion                    488877.0    0.341582      0.195441  0.000653
# ...

# %%
#df.drop(["emoji_count_per_action","max_repetitive_punc","avgt2"],axis = 1 , inplace = True)

# %%
#df_.drop(["emoji_count_per_action","max_repetitive_punc","avgt2"],axis = 1 , inplace = True)

# %%
#num_of_hashtags_per_action , emoji_count_per_action , punctuations_per_action , avgComments , num_of_comments

# %%
#data['logarithm_base2'] = np.log2(data['Salary']

# %%
#df["following_rate"]np.log10(df["following_rate"])

#df

# %%
#for i in df.columns:
#    df.replace(to_replace = )

# %%
#df.replace(to_replace =["Boston Celtics", "Texas"],  
#                            value ="Omega Warrior")

# %%
#for i in df.columns:
#    df[i] = df[i].map( lambda x : df[i].mean() if x == 0 else x)

# %%
df.describe().T
# Out:
#                                     count        mean           std       min  \
# tier                             488877.0    1.975382      0.430707  1.000000
# gender                           488877.0    1.213037      0.409454  1.000000
# following_rate                   488877.0    0.082233      2.467781  0.000000
# followers_avg_age                488877.0    0.347520      0.816334  0.000000
# following_avg_age                488877.0    0.403049      0.925291  0.000000
# max_repetitive_punc              488877.0    0.739748      3.075954  0.000000
# num_of_hashtags_per_action       488877.0    0.000277      0.012221  0.000000
# emoji_count_per_action           488877.0    0.000981      0.020381  0.000000
# punctuations_per_action          488877.0    0.012805      0.159553  0.000000
# number_of_words_per_action       488877.0    0.179148      0.647588  0.000000
# avgCompletion                    488877.0    0.341582      0.195441  0.000653
# ...

# %%
df["total"] = (df["slot1_trails_watched_per_day"]+df["slot2_trails_watched_per_day"]+df["slot3_trails_watched_per_day"]+df["slot4_trails_watched_per_day"])/4

# %%
df_["total"] = (df_["slot1_trails_watched_per_day"]+df_["slot2_trails_watched_per_day"]+df_["slot3_trails_watched_per_day"]+df_["slot4_trails_watched_per_day"])/4

# %%
df.drop(["slot1_trails_watched_per_day","slot2_trails_watched_per_day","slot3_trails_watched_per_day","slot4_trails_watched_per_day"],axis = 1,inplace = True)

# %%
df_.drop(["slot1_trails_watched_per_day","slot2_trails_watched_per_day","slot3_trails_watched_per_day","slot4_trails_watched_per_day"],axis = 1,inplace = True)

# %%
df.head()
# Out:
#           tier  gender  following_rate  followers_avg_age  following_avg_age  \
# userId
# 48958844     2       1             0.0                0.0                0.0
# 51100441     2       2             0.0                0.0                0.0
# 6887426      2       1             0.0                0.0                0.0
# 50742404     2       1             0.0                0.0                0.0
# 45589200     2       2             0.0                0.0                0.0
#
#           max_repetitive_punc  num_of_hashtags_per_action  \
# userId
# 48958844                    0                         0.0
# 51100441                    0                         0.0
# 6887426                     0                         0.0
# 50742404                    0                         0.0
# 45589200                    0                         0.0
#
#           emoji_count_per_action  punctuations_per_action  \
# userId
# 48958844                     0.0                 0.000000
# ...

# %%
df['following_rate']=df['following_rate'].replace(0,df['following_rate'].mean())
df['followers_avg_age']=df['followers_avg_age'].replace(0,df['followers_avg_age'].mean())
df['following_avg_age']=df['following_avg_age'].replace(0,df['following_avg_age'].mean())
df['num_of_hashtags_per_action']=df['num_of_hashtags_per_action'].replace(0,df['num_of_hashtags_per_action'].mean())
df['punctuations_per_action']=df['punctuations_per_action'].replace(0,df['punctuations_per_action'].mean())
df['number_of_words_per_action']=df['number_of_words_per_action'].replace(0,df['number_of_words_per_action'].mean())
df['avgCompletion']=df['avgCompletion'].replace(0,df['avgCompletion'].mean())
df['avgTimeSpent']=df['avgTimeSpent'].replace(0,df['avgTimeSpent'].mean())
df['avgDuration']=df['avgDuration'].replace(0,df['avgDuration'].mean())
df['avgComments']=df['avgComments'].replace(0,df['avgComments'].mean())
df['creations']=df['creations'].replace(0,df['creations'].mean())
df['content_views']=df['content_views'].replace(0,df['content_views'].mean())
df['num_of_comments']=df['num_of_comments'].replace(0,df['num_of_comments'].mean())
df['weekends_trails_watched_per_day']=df['weekends_trails_watched_per_day'].replace(0,df['weekends_trails_watched_per_day'].mean())
df['weekdays_trails_watched_per_day']=df['weekdays_trails_watched_per_day'].replace(0,df['weekdays_trails_watched_per_day'].mean())

# %%
df_['following_rate']=df_['following_rate'].replace(0,df_['following_rate'].mean())
df_['followers_avg_age']=df_['followers_avg_age'].replace(0,df_['followers_avg_age'].mean())
df_['following_avg_age']=df_['following_avg_age'].replace(0,df_['following_avg_age'].mean())
df_['num_of_hashtags_per_action']=df_['num_of_hashtags_per_action'].replace(0,df_['num_of_hashtags_per_action'].mean())
df_['punctuations_per_action']=df_['punctuations_per_action'].replace(0,df_['punctuations_per_action'].mean())
df_['number_of_words_per_action']=df_['number_of_words_per_action'].replace(0,df_['number_of_words_per_action'].mean())
df_['avgCompletion']=df['avgCompletion'].replace(0,df_['avgCompletion'].mean())
df_['avgTimeSpent']=df_['avgTimeSpent'].replace(0,df_['avgTimeSpent'].mean())
df_['avgDuration']=df_['avgDuration'].replace(0,df_['avgDuration'].mean())
df_['avgComments']=df_['avgComments'].replace(0,df_['avgComments'].mean())
df_['creations']=df_['creations'].replace(0,df_['creations'].mean())
df_['content_views']=df_['content_views'].replace(0,df_['content_views'].mean())
df_['num_of_comments']=df_['num_of_comments'].replace(0,df_['num_of_comments'].mean())
df_['weekends_trails_watched_per_day']=df_['weekends_trails_watched_per_day'].replace(0,df_['weekends_trails_watched_per_day'].mean())
df_['weekdays_trails_watched_per_day']=df_['weekdays_trails_watched_per_day'].replace(0,df_['weekdays_trails_watched_per_day'].mean())

# %%
df
# Out:
#           tier  gender  following_rate  followers_avg_age  following_avg_age  \
# userId
# 48958844     2       1        0.082233            0.34752           0.403049
# 51100441     2       2        0.082233            0.34752           0.403049
# 6887426      2       1        0.082233            0.34752           0.403049
# 50742404     2       1        0.082233            0.34752           0.403049
# 45589200     2       2        0.082233            0.34752           0.403049
# ...        ...     ...             ...                ...                ...
# 38983571     2       2        0.082233            0.34752           0.403049
# 53264639     1       1        0.017241            0.34752           0.403049
# 44693578     1       1        0.229508            1.62500           2.250000
# 42760145     2       1        0.082233            0.34752           0.403049
# 42482997     2       1        0.082233            0.34752           0.403049
#
# ...

# %%
df1=df.reindex(columns= ["tier","gender","following_rate","followers_avg_age","following_avg_age","num_of_hashtags_per_action","punctuations_per_action","number_of_words_per_action","avgCompletion","avgTimeSpent","avgDuration","avgComments","creations","content_views","num_of_comments","weekends_trails_watched_per_day","weekdays_trails_watched_per_day","total","age_group"])

# %%
df_1=df_.reindex(columns= ["tier","gender","following_rate","followers_avg_age","following_avg_age","num_of_hashtags_per_action","punctuations_per_action","number_of_words_per_action","avgCompletion","avgTimeSpent","avgDuration","avgComments","creations","content_views","num_of_comments","weekends_trails_watched_per_day","weekdays_trails_watched_per_day","total"])

# %%
df_1
# Out:
#           tier  gender  following_rate  followers_avg_age  following_avg_age  \
# userId
# 33840667     2       1        0.081204           0.344033           0.397432
# 1828421      2       1        0.001818           0.344033           0.397432
# 57353310     2       1        0.081204           0.344033           0.397432
# 36618563     2       2        0.081204           0.344033           0.397432
# 39484434     2       1        0.081204           0.344033           0.397432
# ...        ...     ...             ...                ...                ...
# 56503645     2       1        0.081204           0.344033           0.397432
# 39840927     1       1        0.177419           1.666667           2.210526
# 68398375     2       1        0.048387           0.344033           0.397432
# 51709440     1       2        0.081204           0.344033           0.397432
# 50995322     3       1        0.081204           0.344033           0.397432
#
# ...

# %%
x = df.iloc[:, :-1]#.values
y = df.iloc[:,-1]#.values

# %%
x['following_rate']=np.log(df['following_rate'])
x['followers_avg_age']=np.log(df['followers_avg_age'])
x['following_avg_age']=np.log(df['following_avg_age'])
x['num_of_hashtags_per_action']=np.log(df['num_of_hashtags_per_action'])
x['punctuations_per_action']=np.log(df['punctuations_per_action'])
x['number_of_words_per_action']=np.log(df['number_of_words_per_action'] )
x['avgTimeSpent']=np.log(df['avgTimeSpent'])
x['avgDuration']=np.log(df['avgDuration'])
x['avgComments']=np.log(df['avgComments'])
x['creations']=np.log(df['creations'])
x['content_views']=np.log(df['content_views'])
x['num_of_comments']=np.log(df['num_of_comments'])
x['weekends_trails_watched_per_day']=np.log(df['weekends_trails_watched_per_day'])
x['weekdays_trails_watched_per_day']=np.log(df['weekdays_trails_watched_per_day'])

# %%
#exp = x.copy()

# %%
#exp = exp.drop(["avgTimeSpent","avgDuration","avgt2"],axis=1)

# %%
#exp.shape

# %%
#exp.describe().T

# %%
# Decision Tree for feature importance
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
# fit the model
model.fit(x, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.00727
# Feature: 1, Score: 0.00429
# Feature: 2, Score: 0.02722
# Feature: 3, Score: 0.01119
# Feature: 4, Score: 0.01064
# Feature: 5, Score: 0.00996
# Feature: 6, Score: 0.00009
# Feature: 7, Score: 0.00062
# Feature: 8, Score: 0.00491
# Feature: 9, Score: 0.04081
# Feature: 10, Score: 0.04366
# Feature: 11, Score: 0.04811
# Feature: 12, Score: 0.04747
# Feature: 13, Score: 0.00308
# Feature: 14, Score: 0.45889
# Feature: 15, Score: 0.04278
# Feature: 16, Score: 0.00593
# Feature: 17, Score: 0.03023
# Feature: 18, Score: 0.04470
# Feature: 19, Score: 0.01295
# Feature: 20, Score: 0.03074
# Feature: 21, Score: 0.03114
# Feature: 22, Score: 0.03372
# Feature: 23, Score: 0.04961

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488877 entries, 48958844 to 42482997
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   tier                             488877 non-null  int64
#  1   gender                           488877 non-null  int64
#  2   following_rate                   488877 non-null  float64
#  3   followers_avg_age                488877 non-null  float64
#  4   following_avg_age                488877 non-null  float64
#  5   max_repetitive_punc              488877 non-null  int64
#  6   num_of_hashtags_per_action       488877 non-null  float64
#  7   emoji_count_per_action           488877 non-null  float64
#  8   punctuations_per_action          488877 non-null  float64
#  9   number_of_words_per_action       488877 non-null  float64
#  10  avgCompletion                    488877 non-null  float64
# ...

# %%
matplotlib.style.use('ggplot')

x.hist(alpha=0.5, figsize=(16, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002309EFEBBE0>,
# ...
#       dtype=object)

# %%
for i in x.columns:
    plt.figure()
    sns.kdeplot(x[i])

# %%
for i in x.columns:
    plt.figure()
    sns.boxplot(x[i])

# %%
#sns.pairplot(x)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
#from sklearn.preprocessing import MinMaxScaler
#norm = MinMaxScaler()
#X_train = norm.fit_transform(X_train)
#X_test = norm.transform(X_test)
#test = norm.transform(df_)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
test = sc.transform(df_)

# %%
#from imblearn.over_sampling import SMOTE 
#sm = SMOTE(random_state = 2) 
#X_train, y_train = sm.fit_sample(X_train, y_train)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
#from sklearn.svm import SVC
#classifier = SVC(kernel = 'linear', random_state = 0)
#classifier.fit(X_train,y_train)

# %%
#from sklearn.neighbors import KNeighborsClassifier
#classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
#classifier.fit(X_train, y_train)

# %%
#from sklearn.linear_model import LogisticRegression
#classifier = LogisticRegression(random_state = 0)
#classifier.fit(X_train, y_train)

# %%
#from sklearn.naive_bayes import GaussianNB
#classifier = GaussianNB()
#classifier.fit(X_train, y_train)

# %%
#from sklearn.ensemble import RandomForestClassifier
#classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
#classifier.fit(X_train, y_train)

# %%
#from sklearn.svm import SVC
#classifier = SVC(kernel = 'rbf', random_state = 0)
#classifier.fit(X_train, y_train)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score , classification_report
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm) 
accuracy_score(y_test, y_pred)
# Out:
# [[54574  2405  2332  2478]
#  [ 2401  4860  2302  2291]
#  [ 2357  2169  4347  3106]
#  [ 2341  2146  3205  4462]]
# 0.6979524627720504

# %%
 print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.88      0.88      0.88     61789
#            2       0.42      0.41      0.41     11854
#            3       0.36      0.36      0.36     11979
#            4       0.36      0.37      0.36     12154
#
#     accuracy                           0.70     97776
#    macro avg       0.51      0.51      0.51     97776
# weighted avg       0.70      0.70      0.70     97776

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 69.29 %
# Standard Deviation: 0.21 %

# %%
y_pred_test = classifier.predict(test)
#cm = confusion_matrix(y_test, y_pred)
#print(cm)
#accuracy_score(y_test, y_pred)

# %%
#y_pred = classifer.predict(X_test)
np.set_printoptions(precision=2)
print((y_pred.reshape(len(y_pred),1)))
# Out:
# [[1]
#  [1]
#  [4]
#  ...
#  [1]
#  [3]
#  [2]]

# %%
print((y_pred_test.reshape(len(y_pred_test),1)))
# Out:
# [[1]
#  [1]
#  [1]
#  ...
#  [3]
#  [1]
#  [1]]

# %%
ab = pd.DataFrame(y_pred_test.reshape(len(y_pred_test),1))

# %%
ab.to_csv("sample_test.csv", header = ["prediction"] , index = False)
